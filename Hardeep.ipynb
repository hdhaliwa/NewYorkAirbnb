# %% [markdown]
# <a href="https://colab.research.google.com/github/hdhaliwa/NewYorkAirbnb/blob/master/Hardeep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
File2 = pd.read_csv("https://raw.githubusercontent.com/hdhaliwa/NewYorkAirbnb/master/AB_NYC_2019.csv")

# %%
File2.head(15)
# Out:
#       id  ... availability_365
# 0   2539  ...              365
# 1   2595  ...              355
# 2   3647  ...              365
# 3   3831  ...              194
# 4   5022  ...                0
# 5   5099  ...              129
# 6   5121  ...                0
# 7   5178  ...              220
# 8   5203  ...                0
# 9   5238  ...              188
# 10  5295  ...                6
# 11  5441  ...               39
# 12  5803  ...              314
# 13  6021  ...              333
# 14  6090  ...                0
#
# [15 rows x 16 columns]

# %%
File2
# Out:
#              id  ... availability_365
# 0          2539  ...              365
# 1          2595  ...              355
# 2          3647  ...              365
# 3          3831  ...              194
# 4          5022  ...                0
# 5          5099  ...              129
# 6          5121  ...                0
# 7          5178  ...              220
# 8          5203  ...                0
# 9          5238  ...              188
# 10         5295  ...                6
# 11         5441  ...               39
# 12         5803  ...              314
# 13         6021  ...              333
# 14         6090  ...                0
# 15         6848  ...               46
# 16         7097  ...              321
# 17         7322  ...               12
# 18         7726  ...               21
# 19         7750  ...              249
# 20         7801  ...                0
# 21         8024  ...              347
# 22         8025  ...              364
# 23         8110  ...              304
# ...
